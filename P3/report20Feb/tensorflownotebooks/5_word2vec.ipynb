# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# 351
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-9402be12f283> in <module>()
#      14   return filename
#      15
# ---> 16 filename = maybe_download('text8.zip', 31344016)
#
# <ipython-input-5-9402be12f283> in maybe_download(filename, expected_bytes)
#      11     print(statinfo.st_size)
#      12     raise Exception(
# ---> 13       'Failed to verify ' + filename + '. Can you get to it with a browser?')
#      14   return filename
#      15
#
# Exception: Failed to verify text8.zip. Can you get to it with a browser?

# %% [markdown]
# Read the data into a string.

# %%
filename = 'text8.zip'

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'term', 'originated', 'of', 'as']

# %%
for bi in batch:
    print(bi)
# Out:
# 12
# 12
# 12
# 12
# 6
# 6
# 6
# 6

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.785831
# Nearest to can: hindering, widths, laugh, ist, livy, incoherent, smyrnaeans, ndp,
# Nearest to d: sfsr, armenia, afx, burnt, gemstone, summer, ciuszko, wis,
# Nearest to state: compactification, acids, uniform, going, nordisk, keats, repealed, hounds,
# Nearest to three: ravaging, particles, nonexistence, anode, junit, resin, carolyn, demilitarized,
# Nearest to between: avraham, plasma, paranoid, ugric, hava, adds, miso, fountains,
# Nearest to such: coincidental, animaniacs, gunnery, inhibitory, viii, bacteria, mercantile, pinning,
# Nearest to on: clavichord, damnation, jaws, beneficiary, nikita, effective, hills, banna,
# Nearest to people: tries, synergy, factually, remake, warping, aalen, ij, yarns,
# Nearest to into: loans, shank, topographical, radio, stuart, wasps, northumberland, lusitani,
# Nearest to i: vegetation, nicole, dimer, canso, synthetic, cpsu, aliens, lebesgue,
# Nearest to would: ruben, fearing, liebig, mctell, silvery, offset, edomites, landing,
# Nearest to also: passover, przewodnicz, mlb, murron, stopper, evaporation, nominated, officiate,
# Nearest to but: contestant, unsurprisingly, foil, untreated, slips, brackets, fadh, discernable,
# Nearest to history: mayor, satisfies, stormbringer, gions, abode, deposed, benito, telemetry,
# Nearest to to: plaques, exhaust, stroustrup, proudest, solfege, seniors, virginian, siamese,
# Nearest to with: schaefer, paths, diabetes, literatures, divided, communist, fischer, topologically,
# Average loss at step 2000: 4.363610
# Average loss at step 4000: 3.869662
# Average loss at step 6000: 3.785275
# Average loss at step 8000: 3.688358
# Average loss at step 10000: 3.610348
# Nearest to can: beli, would, could, will, may, smyrnaeans, grapheme, should,
# Nearest to d: ciuszko, b, burnt, bush, austerlitz, deaths, bayezid, gilbertese,
# Nearest to state: going, destructive, dissipates, nordisk, keats, flirt, compactification, acids,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Nearest to between: with, avraham, ugric, paranoid, lottery, plasma, miso, keratin,
# Nearest to such: coincidental, sindhu, hilton, sublimation, juggling, orosius, schaefer, bakassi,
# Nearest to on: in, octaves, avatar, carradine, jaws, by, reviewed, counsels,
# Nearest to people: tries, fin, everquest, uribe, blavatsky, archimedean, commissioned, outgrowth,
# Nearest to into: from, topographical, loans, calvert, stuart, mystical, lunar, radio,
# Nearest to i: vegetation, fares, he, theism, ita, notting, synthetic, valpara,
# Nearest to would: could, can, will, may, klaproth, to, should, chipmunks,
# Nearest to also: often, it, sunset, not, passover, galley, who, micha,
# Nearest to but: unsurprisingly, vanessa, redactor, foil, see, it, quite, concerns,
# Nearest to history: mayor, papadopoulos, wipo, telemetry, benito, subtly, morita, north,
# Nearest to to: would, specs, not, will, outposts, suggestion, replenished, reversible,
# Nearest to with: between, in, for, spoofed, knew, unsolicited, diabetes, cyber,
# Average loss at step 12000: 3.606576
# Average loss at step 14000: 3.570657
# Average loss at step 16000: 3.411985
# Average loss at step 18000: 3.457535
# Average loss at step 20000: 3.536139
# Nearest to can: may, would, could, will, should, cannot, beli, might,
# Nearest to d: b, diomedes, austerlitz, bayezid, lightbulb, dare, deaths, verifies,
# Nearest to state: dissipates, going, slots, flirt, lomo, destructive, positively, compactification,
# Nearest to three: four, five, six, seven, two, eight, one, zero,
# Nearest to between: with, ugric, avraham, lottery, glowing, plasma, paranoid, rhead,
# Nearest to such: these, well, coincidental, other, sindhu, known, certain, pacemaker,
# Nearest to on: in, at, upon, octaves, damnation, instrumentalist, reservoirs, designing,
# Nearest to people: tries, uribe, fin, others, blavatsky, balked, prism, outgrowth,
# Nearest to into: from, calvert, topographical, mystical, by, loans, interruptions, radio,
# Nearest to i: ii, fares, theism, we, p, cahn, valpara, mishneh,
# Nearest to would: could, will, can, may, should, to, must, klaproth,
# Nearest to also: often, widely, which, not, generally, then, who, now,
# Nearest to but: does, did, which, and, however, while, that, amerindians,
# Nearest to history: mayor, biarritz, telemetry, morita, wipo, subtly, squeak, gulf,
# Nearest to to: would, will, not, specs, fantastical, may, can, must,
# Nearest to with: between, for, in, diabetes, by, after, vigesimal, longshanks,
# Average loss at step 22000: 3.501301
# Average loss at step 24000: 3.492743
# Average loss at step 26000: 3.482898
# Average loss at step 28000: 3.480854
# Average loss at step 30000: 3.499808
# Nearest to can: may, would, will, could, should, cannot, must, might,
# Nearest to d: b, diomedes, ghostly, austerlitz, verifies, mclean, zf, rubidium,
# Nearest to state: slots, dissipates, flirt, going, column, lomo, keats, city,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to between: with, miso, lottery, plasma, ugric, avraham, including, within,
# Nearest to such: well, these, known, some, certain, destruct, sindhu, comprising,
# Nearest to on: upon, octaves, in, at, from, throughout, grafton, unicellular,
# Nearest to people: uribe, fin, balked, things, blavatsky, children, others, words,
# Nearest to into: from, mystical, radio, without, instrumentalist, calvert, on, loans,
# Nearest to i: ii, fares, we, theism, iii, they, cahn, marin,
# Nearest to would: will, could, may, can, should, must, might, did,
# Nearest to also: often, widely, now, it, translocation, which, sunset, generally,
# Nearest to but: however, and, which, though, when, although, while, that,
# Nearest to history: biarritz, gulf, squeak, disco, names, papadopoulos, wipo, telemetry,
# Nearest to to: will, would, can, not, specs, should, outposts, could,
# Nearest to with: between, including, by, for, in, longshanks, dickinson, when,
# Average loss at step 32000: 3.500726
# Average loss at step 34000: 3.494655
# Average loss at step 36000: 3.452029
# Average loss at step 38000: 3.296271
# Average loss at step 40000: 3.429396
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to d: b, tipping, diomedes, sfsr, leo, rubidium, verifies, austerlitz,
# Nearest to state: dissipates, slots, positively, column, lomo, profiled, laissez, compactification,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to between: with, within, miso, plasma, ugric, from, lottery, nest,
# Nearest to such: these, well, known, certain, destruct, those, some, many,
# Nearest to on: upon, octaves, at, grafton, carradine, warriors, ordaining, thirties,
# Nearest to people: tries, children, tiff, abkhazian, prism, men, twelve, outgoing,
# Nearest to into: from, through, mystical, oration, without, eddic, around, radio,
# Nearest to i: ii, we, fares, you, he, they, she, iii,
# Nearest to would: will, could, can, may, should, must, did, might,
# Nearest to also: often, now, which, sometimes, usually, never, generally, widely,
# Nearest to but: however, and, while, although, though, banda, which, leaving,
# Nearest to history: disco, squeak, gulf, biarritz, suffragist, papadopoulos, list, classification,
# Nearest to to: specs, will, replenished, offset, arden, would, cannot, indonesian,
# Nearest to with: between, by, nig, kristina, gruesome, including, when, in,
# Average loss at step 42000: 3.434205
# Average loss at step 44000: 3.455489
# Average loss at step 46000: 3.452384
# Average loss at step 48000: 3.351855
# Average loss at step 50000: 3.381368
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to d: b, p, g, austerlitz, e, diomedes, t, herzog,
# Nearest to state: slots, positively, lomo, laissez, blows, division, compactification, dependency,
# Nearest to three: six, four, seven, eight, five, nine, two, zero,
# Nearest to between: with, within, miso, ugric, nest, through, plasma, cli,
# Nearest to such: well, these, known, certain, many, cons, destruct, sindhu,
# Nearest to on: upon, in, octaves, at, grafton, over, compuserve, instrumentalist,
# Nearest to people: children, men, abkhazian, twelve, words, reign, amalric, parties,
# Nearest to into: from, through, around, mystical, instrumentalist, rios, fracture, infiltration,
# Nearest to i: ii, we, you, fares, q, justicia, t, circumpolar,
# Nearest to would: will, could, may, can, should, must, did, might,
# Nearest to also: often, now, which, then, usually, generally, sometimes, never,
# Nearest to but: however, although, while, though, and, when, which, lost,
# Nearest to history: squeak, disco, list, biarritz, carniola, moshe, swordsmen, hall,
# Nearest to to: inhibitory, plaques, outposts, felis, offset, would, through, impairments,
# Nearest to with: between, longshanks, kristina, diabetes, degas, advertise, gangsters, explainable,
# Average loss at step 52000: 3.434539
# Average loss at step 54000: 3.421641
# Average loss at step 56000: 3.436635
# Average loss at step 58000: 3.392962
# Average loss at step 60000: 3.394384
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to d: b, t, h, leo, g, rubidium, hearth, vip,
# Nearest to state: slots, states, government, lomo, blows, positively, position, dependency,
# Nearest to three: five, six, four, eight, seven, two, nine, one,
# Nearest to between: with, among, within, in, latham, nest, plasma, ugric,
# Nearest to such: well, these, known, many, certain, qm, including, diner,
# Nearest to on: upon, instrumentalist, in, through, ornamental, antarctic, bain, baleen,
# Nearest to people: men, children, individuals, twelve, abkhazian, scholars, others, god,
# Nearest to into: from, through, over, mystical, instrumentalist, around, within, rios,
# Nearest to i: ii, we, fares, you, not, t, he, whither,
# Nearest to would: will, could, may, can, must, should, might, did,
# Nearest to also: now, often, sometimes, still, actually, generally, usually, then,
# Nearest to but: however, although, and, when, while, see, which, though,
# Nearest to history: list, biarritz, moshe, disco, suffragist, antithetical, psychologically, gulf,
# Nearest to to: offset, not, would, specs, virginian, will, vom, outposts,
# Nearest to with: between, including, kristina, when, longshanks, thanksgiving, by, mastered,
# Average loss at step 62000: 3.236983
# Average loss at step 64000: 3.253536
# Average loss at step 66000: 3.404749
# Average loss at step 68000: 3.392120
# Average loss at step 70000: 3.357318
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to d: b, h, g, leo, diomedes, rubidium, n, hearth,
# Nearest to state: states, flirt, city, government, blows, column, discrepancies, repealed,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to between: with, within, among, nest, ugric, fonseca, through, plasma,
# Nearest to such: these, well, known, many, certain, peshitta, some, qm,
# Nearest to on: upon, in, through, within, instrumentalist, ornamental, vigour, electromagnetic,
# Nearest to people: men, children, individuals, women, abkhazian, players, twelve, others,
# Nearest to into: from, through, in, mystical, around, instrumentalist, fracture, rios,
# Nearest to i: ii, we, you, fares, t, lamas, g, rancher,
# Nearest to would: will, could, may, can, should, might, must, did,
# Nearest to also: now, often, sometimes, still, generally, actually, which, never,
# Nearest to but: however, although, which, while, that, and, see, though,
# Nearest to history: list, biarritz, bandai, individualist, period, antithetical, brilliance, disco,
# Nearest to to: will, would, can, must, could, offset, in, cannot,
# Nearest to with: between, including, kristina, longshanks, dickinson, diabetes, into, by,
# Average loss at step 72000: 3.371931
# Average loss at step 74000: 3.354488
# Average loss at step 76000: 3.311381
# Average loss at step 78000: 3.344265
# Average loss at step 80000: 3.378567
# Nearest to can: may, could, will, must, would, cannot, might, should,
# Nearest to d: b, h, rubidium, p, psychometrics, herzog, hearth, g,
# Nearest to state: states, lomo, government, column, leadership, flirt, division, compactification,
# Nearest to three: six, four, seven, five, eight, two, nine, zero,
# Nearest to between: within, among, with, nest, pawn, lottery, plasma, fonseca,
# Nearest to such: these, well, known, including, certain, follows, regarded, peshitta,
# Nearest to on: upon, in, through, vigour, instrumentalist, ornamental, at, inanna,
# Nearest to people: men, children, amalric, individuals, women, players, those, members,
# Nearest to into: through, from, over, within, away, around, fracture, mystical,
# Nearest to i: ii, we, you, g, fares, tamper, alto, compositing,
# Nearest to would: will, could, may, must, can, might, should, did,
# Nearest to also: often, now, sometimes, actually, still, generally, which, translocation,
# Nearest to but: however, although, while, and, though, see, he, which,
# Nearest to history: list, knowles, arabella, disco, squeak, biarritz, web, rival,
# Nearest to to: plaques, would, uncountable, sor, specs, outposts, will, offset,
# Nearest to with: nanette, between, longshanks, kristina, including, wannsee, hatti, by,
# Average loss at step 82000: 3.407161
# Average loss at step 84000: 3.414788
# Average loss at step 86000: 3.389322
# Average loss at step 88000: 3.352546
# Average loss at step 90000: 3.360560
# Nearest to can: may, could, will, must, should, cannot, might, would,
# Nearest to d: b, psychometrics, t, herzog, rubidium, h, sumerian, skyrocketed,
# Nearest to state: states, city, government, lomo, column, leadership, flagging, euclidean,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to between: within, with, among, cli, in, into, pawn, through,
# Nearest to such: known, these, well, certain, follows, many, hellfire, regarded,
# Nearest to on: upon, under, instrumentalist, vigour, ornamental, through, in, at,
# Nearest to people: children, men, women, individuals, god, players, members, amalric,
# Nearest to into: through, from, over, around, between, away, instrumentalist, fracture,
# Nearest to i: ii, we, g, you, q, fares, iv, iii,
# Nearest to would: will, could, may, might, must, can, should, did,
# Nearest to also: often, now, still, which, actually, sometimes, generally, usually,
# Nearest to but: however, and, although, while, which, they, though, until,
# Nearest to history: list, antithetical, squeak, arabella, biarritz, carcasses, psychologically, ingolstadt,
# Nearest to to: will, would, virginian, specs, inhibitory, vom, firefox, luminance,
# Nearest to with: between, diabetes, gruesome, longshanks, in, nanette, by, across,
# Average loss at step 92000: 3.398498
# Average loss at step 94000: 3.255259
# Average loss at step 96000: 3.353489
# Average loss at step 98000: 3.242424
# Average loss at step 100000: 3.354680
# Nearest to can: could, may, must, will, should, cannot, would, might,
# Nearest to d: b, rubidium, diomedes, brava, sumerian, austerlitz, forefathers, steve,
# Nearest to state: city, states, lomo, government, column, slots, hounds, euclidean,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to between: with, among, within, through, cli, fonseca, miso, rhead,
# Nearest to such: known, well, these, certain, many, follows, cited, journeyman,
# Nearest to on: upon, at, in, through, under, towards, instrumentalist, htm,
# Nearest to people: men, children, players, individuals, women, americans, things, amalric,
# Nearest to into: through, from, within, around, fracture, away, in, between,
# Nearest to i: ii, we, you, fares, they, not, v, syncopated,
# Nearest to would: will, could, may, might, can, should, must, did,
# Nearest to also: now, never, actually, sometimes, still, often, who, which,
# Nearest to but: however, although, and, though, while, isolates, which, athabasca,
# Nearest to history: list, carcasses, biarritz, antithetical, individualist, squeak, subnet, imp,
# Nearest to to: will, would, could, can, should, virginian, for, arden,
# Nearest to with: between, including, kristina, across, when, at, into, logistic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    #assert skip_window % 2 == 1

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
    
        col_idx = 0
        for j in range(span):
            if j ==span//2:
                continue
            batch[i,col_idx] = buffer[j]
            col_idx +=1
        labels[i,0] = buffer[target]
    
    
        buffer.append(data[data_index])
        data_index = (data_index +1) % len(data)
        
    
    assert batch.shape[0]==batch_size and batch.shape[1]== span -1

    return batch,labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1,2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('    batch:', [reverse_dictionary[bi[0]] for bi in batch])
    print('    batch:', [reverse_dictionary[bi[1]] for bi in batch])    
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#     batch: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
num_steps = 100001

if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
    # We pick a random validation set to sample nearest neighbors. here we limit the
    # validation samples to the words that have a low numeric ID, which by
    # construction are also the most frequent.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.

    graph = tf.Graph()

    with graph.as_default(), tf.device('/cpu:0'):

        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Model.
        # Look up embeddings for inputs.
        # this might efficiently find the embeddings for given ids (traind dataset)
        # manually doing this might not be efficient given there are 50000 entries in embeddings
        embeds = None
        for i in range(2*skip_window):
            embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
            print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
            emb_x,emb_y = embedding_i.get_shape().as_list()
            if embeds is None:
                embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
            else:
                embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])

        assert embeds.get_shape().as_list()[2]==2*skip_window
        print("Concat embedding size: %s"%embeds.get_shape().as_list())
        avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
        print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

        '''embedding_0 = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
        embedding_1 = tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
        avg_embed =  (embedding_0+embedding_1)/2.0
        print("Avg embedding size: %s"%avg_embed.get_shape().as_list())'''

        # Compute the softmax loss, using a sample of the negative labels each time.
        # inputs are embeddings of the train words
        # with this loss we optimize weights, biases, embeddings

        loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
                               train_labels, num_sampled, vocabulary_size))

        # Optimizer.
        # Note: The optimizer will optimize the softmax_weights AND the embeddings.
        # This is because the embeddings are defined as a variable quantity and the
        # optimizer's `minimize` method will by default modify all variable quantities
        # that contribute to the tensor it is passed.
        # See docs on `tf.train.Optimizer.minimize()` for more details.
        # Adagrad is required because there are too many things to optimize
        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

    with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        print('Initialized')
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(batch_size, skip_window)
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]
# WARNING:tensorflow:From <ipython-input-45-5fc0fc14b319>:83 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.533465
# Nearest to about: burgesses, blink, wr, diseased, younger, swampy, dysprosium, arise,
# Nearest to these: lottery, distal, thoughts, sas, counterculture, backdrop, phoned, perform,
# Nearest to d: lion, novgorod, allison, karnataka, naiste, tron, programming, chios,
# Nearest to was: ease, classroom, bolger, dunsany, lipid, zamora, rogues, bijelo,
# Nearest to have: mists, cornwell, lms, packing, perfection, fijian, overlord, kropotkin,
# Nearest to four: org, wavefunction, enraged, atoms, transmits, biomass, ganglia, nova,
# Nearest to other: sail, versatile, badminton, vest, interactionism, significand, cpr, bystander,
# Nearest to he: bundles, lanka, entombed, eaters, nadia, famines, concordat, synagogue,
# Nearest to square: accorded, restaurants, riso, imperfectly, calvinistic, decimus, argent, basileus,
# Nearest to troops: provocative, servicing, ammunition, enamel, engines, mendelevium, dx, buddhas,
# Nearest to cost: whitby, millet, gkos, tiresias, tighter, monic, abbe, rangers,
# Nearest to recorded: commemorate, pendant, visicalc, factions, gheg, openstep, malian, emily,
# Nearest to applications: borromini, practitioners, menus, rebel, geared, dench, nicomedia, clashing,
# Nearest to active: biotechnology, transit, sonja, tdi, psalm, olmec, stigma, melds,
# Nearest to shown: redundantly, listen, angels, circulate, othon, exorbitant, sunset, condom,
# Nearest to numerous: benoit, elagabalus, shave, parallax, finalised, exclamation, delivery, predictor,
# Average loss at step 2000: 4.031453
# Average loss at step 4000: 3.507646
# Average loss at step 6000: 3.341524
# Average loss at step 8000: 3.193684
# Average loss at step 10000: 3.147491
# Nearest to about: through, immerse, impassable, gurps, wr, rbi, ganz, superstar,
# Nearest to these: many, which, incl, soaked, propped, those, calderas, dearly,
# Nearest to d: b, naiste, lion, americium, hottest, uttering, achievable, shen,
# Nearest to was: is, had, has, were, became, been, nervous, be,
# Nearest to have: had, has, be, are, quoted, were, never, souvenir,
# Nearest to four: eight, six, nine, seven, zero, three, two, five,
# Nearest to other: reworking, different, limewire, scholes, calcutta, titular, ivanov, marcantonio,
# Nearest to he: it, she, they, who, schism, foregoing, never, fidonet,
# Nearest to square: accorded, restaurants, imperfectly, riso, follies, calvinistic, reformed, sampson,
# Nearest to troops: provocative, servicing, ammunition, dx, engines, shreveport, enamel, rely,
# Nearest to cost: whitby, tighter, abbe, vincendeau, millet, tiresias, perpetrator, gkos,
# Nearest to recorded: commemorate, pendant, openstep, malian, gheg, visicalc, factions, rear,
# Nearest to applications: borromini, practitioners, rebel, geared, menus, nicomedia, deed, wenders,
# Nearest to active: biotechnology, transit, sonja, olmec, rushes, stigma, psalm, tdi,
# Nearest to shown: listen, angels, condom, othon, exorbitant, aphids, rumsfeld, redundantly,
# Nearest to numerous: benoit, elagabalus, shave, finalised, exclamation, handlebar, reverence, parallax,
# Average loss at step 12000: 3.165549
# Average loss at step 14000: 3.130879
# Average loss at step 16000: 3.150891
# Average loss at step 18000: 3.101399
# Average loss at step 20000: 2.990984
# Nearest to about: through, ganz, immerse, impassable, confined, sarajevo, unforgettable, wr,
# Nearest to these: many, some, those, which, incl, such, calderas, they,
# Nearest to d: b, naiste, americium, uttering, lion, karnataka, hottest, achievable,
# Nearest to was: is, were, had, has, became, been, be, draugr,
# Nearest to have: had, has, were, are, be, never, quoted, statute,
# Nearest to four: six, eight, five, three, seven, two, nine, zero,
# Nearest to other: different, various, limewire, bargain, reworking, marysville, marcantonio, dissolve,
# Nearest to he: she, it, they, who, never, there, foregoing, schism,
# Nearest to square: accorded, restaurants, imperfectly, calvinistic, riso, follies, marca, reformed,
# Nearest to troops: provocative, servicing, rely, ammunition, dx, engines, calf, enamel,
# Nearest to cost: whitby, tighter, perpetrator, agp, abbe, neighbor, tiresias, pergamum,
# Nearest to recorded: commemorate, pendant, openstep, gheg, malian, hardwicke, satsuma, rear,
# Nearest to applications: borromini, rebel, practitioners, deed, lennox, wenders, marcus, nicomedia,
# Nearest to active: biotechnology, transit, international, sonja, defun, phrygia, olmec, stigma,
# Nearest to shown: listen, angels, rumsfeld, condom, aphids, somerville, roy, othon,
# Nearest to numerous: benoit, shave, mammals, elagabalus, delivery, finalised, theophrastus, exclamation,
# Average loss at step 22000: 3.057059
# Average loss at step 24000: 3.029026
# Average loss at step 26000: 2.987773
# Average loss at step 28000: 3.017578
# Average loss at step 30000: 2.990877
# Nearest to about: sarajevo, ganz, immerse, toxicity, finno, sent, alerted, unforgettable,
# Nearest to these: some, those, many, such, incl, both, which, they,
# Nearest to d: b, naiste, americium, lion, bounding, uttering, smith, affront,
# Nearest to was: is, were, had, became, has, been, be, celebrates,
# Nearest to have: had, has, are, were, never, be, statute, quoted,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to other: various, different, limewire, several, bargain, many, torino, marcantonio,
# Nearest to he: she, it, they, who, never, there, foregoing, grabs,
# Nearest to square: accorded, restaurants, imperfectly, calvinistic, marca, riso, sleepers, impedes,
# Nearest to troops: provocative, servicing, ammunition, rely, dx, calf, engines, enamel,
# Nearest to cost: whitby, tighter, perpetrator, pergamum, edwina, agp, neighbor, abbe,
# Nearest to recorded: seen, commemorate, pendant, held, gheg, satsuma, malian, mundar,
# Nearest to applications: borromini, deed, rebel, lennox, wenders, practitioners, nicomedia, freenode,
# Nearest to active: biotechnology, transit, international, defun, sonja, servicio, phrygia, stigma,
# Nearest to shown: rumsfeld, listen, angels, somerville, aphids, copernicus, condom, glycolipids,
# Nearest to numerous: benoit, mammals, shave, delivery, theophrastus, elagabalus, exclamation, ufc,
# Average loss at step 32000: 2.842211
# Average loss at step 34000: 2.949884
# Average loss at step 36000: 2.938856
# Average loss at step 38000: 2.936213
# Average loss at step 40000: 2.917663
# Nearest to about: alerted, sarajevo, sent, ganz, phrased, toxicity, unforgettable, finno,
# Nearest to these: those, such, some, many, which, they, various, both,
# Nearest to d: b, naiste, bounding, americium, novgorod, lion, smith, uttering,
# Nearest to was: is, were, had, became, been, has, celebrates, be,
# Nearest to have: had, has, are, were, never, including, be, dares,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to other: various, different, bargain, several, many, torino, dehydroepiandrosterone, limewire,
# Nearest to he: she, it, they, there, who, never, schism, briefly,
# Nearest to square: accorded, restaurants, imperfectly, limitations, calvinistic, pageant, follies, adb,
# Nearest to troops: provocative, servicing, dx, mommsen, ammunition, severly, engines, caught,
# Nearest to cost: whitby, tighter, perpetrator, agp, pergamum, neighbor, edwina, deployment,
# Nearest to recorded: held, seen, commemorate, satsuma, pendant, gheg, malian, mundar,
# Nearest to applications: deed, borromini, outstanding, practitioners, lennox, wenders, jameson, freenode,
# Nearest to active: biotechnology, defun, transit, international, servicio, phrygia, magnetic, olmec,
# Nearest to shown: rumsfeld, listen, angels, aphids, copernicus, somerville, glycolipids, ciudad,
# Nearest to numerous: mammals, delivery, benoit, shave, many, ufc, theophrastus, milken,
# Average loss at step 42000: 2.939642
# Average loss at step 44000: 2.944457
# Average loss at step 46000: 2.907696
# Average loss at step 48000: 2.871362
# Average loss at step 50000: 2.847120
# Nearest to about: sent, rockin, toxicity, alerted, finno, internetworking, impassable, slack,
# Nearest to these: some, those, many, such, various, they, which, several,
# Nearest to d: b, naiste, smith, americium, utopia, unsatisfactory, detached, bounding,
# Nearest to was: is, became, had, were, been, has, be, celebrates,
# Nearest to have: had, has, are, were, be, include, having, dares,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to other: various, different, bargain, graphite, dehydroepiandrosterone, unamended, limewire, quinlan,
# Nearest to he: she, it, they, there, who, we, foregoing, briefly,
# Nearest to square: accorded, restaurants, imperfectly, limitations, calvinistic, pageant, sleepers, adb,
# Nearest to troops: provocative, mommsen, caught, severly, army, servicing, dx, engines,
# Nearest to cost: whitby, tighter, deployment, pergamum, agp, perpetrator, quality, abbe,
# Nearest to recorded: seen, held, appeared, satsuma, pendant, malian, commemorate, mundar,
# Nearest to applications: programs, outstanding, deed, wenders, freenode, practitioners, products, borromini,
# Nearest to active: biotechnology, defun, international, servicio, extensive, transit, alternative, magnetic,
# Nearest to shown: rumsfeld, listen, found, unable, somerville, aphids, copernicus, believed,
# Nearest to numerous: many, delivery, mammals, benoit, shave, ufc, milken, theophrastus,
# Average loss at step 52000: 2.883276
# Average loss at step 54000: 2.861984
# Average loss at step 56000: 2.858067
# Average loss at step 58000: 2.757534
# Average loss at step 60000: 2.826395
# Nearest to about: rockin, slack, toxicity, alerted, honeys, sent, sarajevo, lucilla,
# Nearest to these: those, such, many, some, several, various, which, they,
# Nearest to d: b, naiste, bounding, utopia, unsatisfactory, americium, smith, r,
# Nearest to was: is, had, became, were, has, been, be, wrote,
# Nearest to have: had, has, were, are, having, dares, remember, gradually,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to other: various, different, bargain, graphite, unamended, mencken, quinlan, appropriately,
# Nearest to he: she, it, they, there, who, we, never, eventually,
# Nearest to square: accorded, restaurants, limitations, imperfectly, sleepers, calvinistic, elsevier, pageant,
# Nearest to troops: army, mommsen, provocative, caught, forces, navy, aid, severly,
# Nearest to cost: whitby, quality, tighter, deployment, perpetrator, pergamum, agp, summer,
# Nearest to recorded: seen, held, appeared, performed, published, featured, satsuma, recognized,
# Nearest to applications: programs, outstanding, products, practitioners, deed, wenders, freenode, stealth,
# Nearest to active: extensive, defun, servicio, international, transit, biotechnology, estranged, phrygia,
# Nearest to shown: rumsfeld, found, seen, unable, somerville, listen, hata, copernicus,
# Nearest to numerous: many, delivery, several, mammals, benoit, shave, shaanxi, milken,
# Average loss at step 62000: 2.832037
# Average loss at step 64000: 2.780160
# Average loss at step 66000: 2.768965
# Average loss at step 68000: 2.717556
# Average loss at step 70000: 2.777627
# Nearest to about: lucilla, rockin, toxicity, slack, sarajevo, that, honeys, ganz,
# Nearest to these: those, some, such, many, several, they, various, both,
# Nearest to d: b, naiste, unsatisfactory, bounding, r, americium, smith, utopia,
# Nearest to was: is, became, had, were, has, be, celebrates, been,
# Nearest to have: had, has, are, were, having, be, include, gradually,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to other: various, different, unamended, bargain, appropriately, mencken, graphite, dehydroepiandrosterone,
# Nearest to he: she, it, they, who, there, we, eventually, briefly,
# Nearest to square: accorded, restaurants, bylaws, pageant, imperfectly, sampson, elsevier, limitations,
# Nearest to troops: army, forces, mommsen, caught, navy, provocative, aid, severly,
# Nearest to cost: quality, whitby, tighter, deployment, perpetrator, agp, pergamum, jurists,
# Nearest to recorded: seen, held, performed, appeared, featured, recognized, published, played,
# Nearest to applications: programs, outstanding, products, freenode, stealth, practitioners, wenders, jameson,
# Nearest to active: extensive, defun, servicio, biotechnology, international, transit, estranged, alternative,
# Nearest to shown: rumsfeld, found, seen, unable, listen, hata, somerville, aphids,
# Nearest to numerous: many, several, delivery, some, mammals, shaanxi, various, benoit,
# Average loss at step 72000: 2.795265
# Average loss at step 74000: 2.657909
# Average loss at step 76000: 2.803809
# Average loss at step 78000: 2.825806
# Average loss at step 80000: 2.783672
# Nearest to about: lucilla, slack, over, toxicity, mutants, convertible, honeys, sarajevo,
# Nearest to these: those, such, many, some, several, various, which, they,
# Nearest to d: b, naiste, r, uttering, topol, bounding, americium, muggles,
# Nearest to was: is, were, became, had, has, been, be, celebrates,
# Nearest to have: had, has, were, are, include, having, gradually, dares,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to other: various, different, bargain, unamended, individual, dehydroepiandrosterone, preacher, graphite,
# Nearest to he: she, it, they, there, who, we, briefly, gradually,
# Nearest to square: accorded, restaurants, pageant, imperfectly, bylaws, calvinistic, limitations, elsevier,
# Nearest to troops: army, forces, navy, mommsen, caught, aid, parliament, severly,
# Nearest to cost: quality, whitby, tighter, deployment, agp, pergamum, perpetrator, crowd,
# Nearest to recorded: seen, held, performed, appeared, featured, recognized, published, played,
# Nearest to applications: programs, outstanding, products, stealth, freenode, practitioners, wenders, artists,
# Nearest to active: extensive, defun, servicio, biotechnology, international, estranged, transit, intestine,
# Nearest to shown: seen, found, rumsfeld, unable, hata, listed, given, treated,
# Nearest to numerous: many, several, delivery, various, shaanxi, mammals, milken, ufc,
# Average loss at step 82000: 2.677442
# Average loss at step 84000: 2.771131
# Average loss at step 86000: 2.742014
# Average loss at step 88000: 2.754456
# Average loss at step 90000: 2.738720
# Nearest to about: over, slack, lucilla, regarding, rockin, mutants, sent, silurian,
# Nearest to these: those, such, many, various, some, several, certain, they,
# Nearest to d: b, r, naiste, bounding, topol, uttering, affront, flask,
# Nearest to was: is, became, has, had, becomes, were, been, be,
# Nearest to have: had, has, are, were, having, remember, include, gradually,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to other: various, different, bargain, others, unamended, dehydroepiandrosterone, individual, many,
# Nearest to he: she, it, they, there, we, who, briefly, gradually,
# Nearest to square: accorded, restaurants, imperfectly, pageant, bylaws, limitations, elsevier, calvinistic,
# Nearest to troops: army, forces, navy, mommsen, soldiers, armies, caught, severly,
# Nearest to cost: quality, whitby, deployment, number, tighter, amount, edge, pergamum,
# Nearest to recorded: seen, held, performed, featured, appeared, published, recognized, celebrated,
# Nearest to applications: programs, outstanding, products, practitioners, wenders, services, stealth, freenode,
# Nearest to active: extensive, defun, servicio, estranged, international, biotechnology, transit, intestine,
# Nearest to shown: seen, found, rumsfeld, listed, unable, hata, done, given,
# Nearest to numerous: many, several, various, delivery, some, shaanxi, addington, mammals,
# Average loss at step 92000: 2.688101
# Average loss at step 94000: 2.724894
# Average loss at step 96000: 2.708504
# Average loss at step 98000: 2.384973
# Average loss at step 100000: 2.420487
# Nearest to about: slack, lucilla, rockin, over, regarding, mystical, convertible, on,
# Nearest to these: those, such, various, many, several, some, certain, they,
# Nearest to d: b, naiste, bounding, achievable, uttering, enrico, topol, utopia,
# Nearest to was: is, became, had, were, has, wrote, be, began,
# Nearest to have: had, has, are, were, having, include, remember, contain,
# Nearest to four: seven, five, six, eight, three, nine, zero, two,
# Nearest to other: various, others, different, unamended, individual, manichean, bargain, preacher,
# Nearest to he: she, it, they, there, we, who, briefly, gradually,
# Nearest to square: accorded, restaurants, pageant, imperfectly, bylaws, limitations, elsevier, calvinistic,
# Nearest to troops: forces, army, soldiers, navy, caught, armies, mommsen, fleet,
# Nearest to cost: quality, deployment, whitby, tighter, edge, amount, crowd, end,
# Nearest to recorded: seen, held, performed, published, featured, appeared, celebrated, recognized,
# Nearest to applications: programs, services, outstanding, products, freenode, practitioners, wenders, stealth,
# Nearest to active: extensive, servicio, estranged, defun, biotechnology, international, transit, educational,
# Nearest to shown: seen, found, listed, rumsfeld, done, hata, unable, mentioned,
# Nearest to numerous: many, several, various, some, delivery, shaanxi, mammals, multiple,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
